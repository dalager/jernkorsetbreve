# %%
import json
import importlib
from MLStripper import strip_tags
from datetime import datetime
import create_epub

# %%
importlib.reload(create_epub)
letters = create_epub.load_csv()
create_epub.create_epub(letters,'jernkorset.epub')

# %%
# find all letters where the word "postkort" is mentioned
letters[letters['text'].str.contains('fotografi',case=False,regex=True)]
# Out:
#       id       date       sender    recipient                          place  \
# 0      1 1911-03-06  Peter Mærsk  Trine Mærsk                 Øster Åbølling
# 5      6 1911-07-06  Peter Mærsk  Trine Mærsk                 Øster Åbølling
# 7      8 1911-08-01  Peter Mærsk  Trine Mærsk                 Øster Åbølling
# 64    65 1914-06-07  Peter Mærsk   Mor og far                            nan
# 169  170 1915-06-11  Peter Mærsk   Mor og far  Branusberg (Braniewo, Poland)
# 172  173 1915-06-22  Peter Mærsk   Mor og far  Branusberg (Braniewo, Poland)
# 179  180 1915-07-23  Peter Mærsk  Trine Mærsk  Branusberg (Braniewo, Poland)
# 317  318 1916-06-09  Peter Mærsk  Trine Mærsk  Dünaburg (Daugavpils, Latvia)
# 331  332 1916-07-09  Peter Mærsk   Mor og far  Dünaburg (Daugavpils, Latvia)
# 344  345 1916-09-20        Konow  Peter Mærsk  Dünaburg (Daugavpils, Latvia)
#
#                     location  \
# 0      55.239613,8.833278,10
# 5      55.239613,8.833278,10
# ...
